# %% [markdown]
# # La Liga (1995 - 2020)

# %% [markdown]
# # Import the libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import the dataset

# %%
data = pd.read_csv('LaLiga_Matches_1995-2020.csv')

# %%
data
# Out:
#        Season        Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     1995-96    2/9/1995   La Coruna     Valencia     3     0   H   2.0
# 1     1995-96    2/9/1995    Sp Gijon     Albacete     3     0   H   3.0
# 2     1995-96    3/9/1995  Ath Bilbao    Santander     4     0   H   2.0
# 3     1995-96    3/9/1995  Ath Madrid     Sociedad     4     1   H   1.0
# 4     1995-96    3/9/1995       Celta   Compostela     0     1   A   0.0
# ...       ...         ...         ...          ...   ...   ...  ..   ...
# 9659  2019-20  19/07/2020     Granada   Ath Bilbao     4     0   H   1.0
# 9660  2019-20  19/07/2020     Leganes  Real Madrid     2     2   D   1.0
# 9661  2019-20  19/07/2020     Levante       Getafe     1     0   H   0.0
# 9662  2019-20  19/07/2020     Osasuna     Mallorca     2     2   D   1.0
# 9663  2019-20  19/07/2020     Sevilla     Valencia     1     0   H   0.0
#
#       HTAG HTR
# 0      0.0   H
# 1      0.0   H
# 2      0.0   H
# 3      1.0   D
# ...

# %% [markdown]
# # Goals scored in home matches in each season

# %%
pivot1 = pd.pivot_table(data,
                       index=['Season'],
                       values=['FTHG'],
                       columns=['HomeTeam'],
                       fill_value='',
                       aggfunc=np.sum)

# %%
pivot1
# Out:
#             FTHG                                                               \
# HomeTeam  Alaves Albacete Almeria Ath Bilbao Ath Madrid Barcelona Betis Cadiz
# Season
# 1995-96              31.0               25.0       40.0      42.0  39.0
# 1996-97                                 41.0       42.0      63.0  44.0
# 1997-98                                 36.0       47.0      42.0  30.0
# 1998-99     25.0                        30.0       37.0      52.0  23.0
# 1999-2000   23.0                        29.0       26.0      42.0  19.0
# 2000-01     34.0                        32.0                 51.0
# 2001-02     22.0                        23.0                 44.0  26.0
# 2002-03     18.0                        30.0       28.0      43.0  31.0
# 2003-04              25.0               32.0       30.0      33.0  22.0
# 2004-05              17.0               39.0       28.0      40.0  36.0
# 2005-06     20.0                        19.0       21.0      45.0  19.0  22.0
# ...

# %%
pivot1['FTHG']['Barcelona'].plot(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Season'>

# %%
pivot1 = pd.pivot_table(data,
                       index=['Season'],
                       values=['FTHG'],
                       columns=['HomeTeam'],
                       fill_value='',
                        aggfunc=np.sum, 
               margins=True, 
               margins_name='Total'
              )

# %%
pivot1
# Out:
#             FTHG                                                               \
# HomeTeam  Alaves Albacete Almeria Ath Bilbao Ath Madrid Barcelona Betis Cadiz
# Season
# 1995-96              31.0               25.0       40.0      42.0  39.0
# 1996-97                                 41.0       42.0      63.0  44.0
# 1997-98                                 36.0       47.0      42.0  30.0
# 1998-99     25.0                        30.0       37.0      52.0  23.0
# 1999-2000   23.0                        29.0       26.0      42.0  19.0
# 2000-01     34.0                        32.0                 51.0
# 2001-02     22.0                        23.0                 44.0  26.0
# 2002-03     18.0                        30.0       28.0      43.0  31.0
# 2003-04              25.0               32.0       30.0      33.0  22.0
# 2004-05              17.0               39.0       28.0      40.0  36.0
# 2005-06     20.0                        19.0       21.0      45.0  19.0  22.0
# ...

# %% [markdown]
# # Goals scored in away matches  in each season

# %%
pivot3 = pd.pivot_table(data,
                       index=['Season'],
                       values=['FTAG'],
                       columns=['AwayTeam'],
                       fill_value='',
                        aggfunc=np.sum
              )

# %%
pivot3
# Out:
#             FTAG                                                               \
# AwayTeam  Alaves Albacete Almeria Ath Bilbao Ath Madrid Barcelona Betis Cadiz
# Season
# 1995-96              24.0               19.0       35.0      30.0  22.0
# 1996-97                                 31.0       34.0      39.0  37.0
# 1997-98                                 16.0       32.0      36.0  19.0
# 1998-99     11.0                        23.0       17.0      35.0  24.0
# 1999-2000   18.0                        18.0       22.0      28.0  14.0
# 2000-01     24.0                        12.0                 29.0
# 2001-02     19.0                        31.0                 21.0  16.0
# 2002-03     20.0                        33.0       23.0      20.0  25.0
# 2003-04              15.0               21.0       21.0      30.0  24.0
# 2004-05              16.0               20.0       12.0      33.0  26.0
# 2005-06     15.0                        21.0       24.0      35.0  15.0  14.0
# ...

# %%
pivot3['FTAG']['Barcelona'].plot(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Season'>

# %%
pivot4 = pd.pivot_table(data,
                       index=['Season'],
                       values=['FTAG'],
                       columns=['AwayTeam'],
                       fill_value='',
                        aggfunc=np.sum, 
               margins=True, 
               margins_name='Total'
              )

# %%
pivot4
# Out:
#             FTAG                                                               \
# AwayTeam  Alaves Albacete Almeria Ath Bilbao Ath Madrid Barcelona Betis Cadiz
# Season
# 1995-96              24.0               19.0       35.0      30.0  22.0
# 1996-97                                 31.0       34.0      39.0  37.0
# 1997-98                                 16.0       32.0      36.0  19.0
# 1998-99     11.0                        23.0       17.0      35.0  24.0
# 1999-2000   18.0                        18.0       22.0      28.0  14.0
# 2000-01     24.0                        12.0                 29.0
# 2001-02     19.0                        31.0                 21.0  16.0
# 2002-03     20.0                        33.0       23.0      20.0  25.0
# 2003-04              15.0               21.0       21.0      30.0  24.0
# 2004-05              16.0               20.0       12.0      33.0  26.0
# 2005-06     15.0                        21.0       24.0      35.0  15.0  14.0
# ...
