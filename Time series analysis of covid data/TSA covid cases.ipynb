# %% [markdown]
# # Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.style.use('fivethirtyeight')
import statsmodels.api as sm

# %% [markdown]
# # Import the dataset

# %%
df = pd.read_csv('cov_tsa.csv',parse_dates=['REPORT_DATE'])
df
# Out:
#          PEOPLE_POSITIVE_CASES_COUNT COUNTY_NAME PROVINCE_STATE_NAME  \
# 0                               7844      Oneida            New York
# 1                               1830      Oneida            New York
# 2                               1776      Oneida            New York
# 3                              19215      Oneida            New York
# 4                                676      Oneida            New York
# ...                              ...         ...                 ...
# 1634240                            0         NaN                 NaN
# 1634241                            0         NaN               Macau
# 1634242                            0         NaN                 NaN
# 1634243                            0         NaN                 NaN
# 1634244                            0         NaN                 NaN
#
#         REPORT_DATE CONTINENT_NAME            DATA_SOURCE_NAME  \
# 0        2020-12-13        America              New York Times
# 1        2020-07-13        America              New York Times
# 2        2020-07-08        America              New York Times
# 3        2021-02-16        America              New York Times
# 4        2020-05-12        America              New York Times
# ...             ...            ...                         ...
# 1634240  2020-01-21        America  JHU CSSE Global Timeseries
# 1634241  2020-01-21           Asia  JHU CSSE Global Timeseries
# 1634242  2020-01-21        America  JHU CSSE Global Timeseries
# 1634243  2020-01-21         Europe  JHU CSSE Global Timeseries
# 1634244  2020-01-21         Africa  JHU CSSE Global Timeseries
#
#          PEOPLE_DEATH_NEW_COUNT  COUNTY_FIPS_NUMBER COUNTRY_ALPHA_3_CODE  \
# 0                             1             36065.0                  USA
# 1                             3             36065.0                  USA
# 2                             1             36065.0                  USA
# 3                             2             36065.0                  USA
# 4                             1             36065.0                  USA
# ...                         ...                 ...                  ...
# 1634240                       0                 NaN                  MAF
# 1634241                       0                 NaN                  CHN
# 1634242                       0                 NaN                  BRB
# 1634243                       0                 NaN                  RUS
# 1634244                       0                 NaN                  NER
#
#         COUNTRY_SHORT_NAME COUNTRY_ALPHA_2_CODE  \
# 0            United States                   US
# 1            United States                   US
# 2            United States                   US
# 3            United States                   US
# 4            United States                   US
# ...                    ...                  ...
# 1634240          St Martin                   MF
# 1634241              China                   CN
# 1634242           Barbados                   BB
# 1634243             Russia                   RU
# 1634244              Niger                   NE
#
#          PEOPLE_POSITIVE_NEW_CASES_COUNT  PEOPLE_DEATH_COUNT
# 0                                    237                 188
# 1                                      7                 104
# 2                                     16                  99
# 3                                     29                 462
# 4                                      7                  26
# ...                                  ...                 ...
# 1634240                                0                   0
# 1634241                                0                   0
# 1634242                                0                   0
# 1634243                                0                   0
# 1634244                                0                   0
#
# [1634245 rows x 13 columns]

# %% [markdown]
# ### Check for missing data

# %%
df.isna().sum()
# Out:
# PEOPLE_POSITIVE_CASES_COUNT             0
# COUNTY_NAME                        124931
# PROVINCE_STATE_NAME                 98654
# REPORT_DATE                             0
# CONTINENT_NAME                       1844
# DATA_SOURCE_NAME                        0
# PEOPLE_DEATH_NEW_COUNT                  0
# COUNTY_FIPS_NUMBER                 150747
# COUNTRY_ALPHA_3_CODE                 1844
# COUNTRY_SHORT_NAME                      0
# COUNTRY_ALPHA_2_CODE                 2305
# PEOPLE_POSITIVE_NEW_CASES_COUNT         0
# PEOPLE_DEATH_COUNT                      0
# dtype: int64

# %% [markdown]
# ###### Remove unwanted columns

# %%
cols=['PEOPLE_POSITIVE_CASES_COUNT','COUNTY_NAME','PROVINCE_STATE_NAME','CONTINENT_NAME','DATA_SOURCE_NAME','COUNTY_FIPS_NUMBER','COUNTRY_ALPHA_3_CODE','COUNTRY_ALPHA_2_CODE','PEOPLE_DEATH_COUNT']
df.drop(cols,axis=1,inplace=True)
df.head()
# Out:
#   REPORT_DATE  PEOPLE_DEATH_NEW_COUNT COUNTRY_SHORT_NAME  \
# 0  2020-12-13                       1      United States
# 1  2020-07-13                       3      United States
# 2  2020-07-08                       1      United States
# 3  2021-02-16                       2      United States
# 4  2020-05-12                       1      United States
#
#    PEOPLE_POSITIVE_NEW_CASES_COUNT
# 0                              237
# 1                                7
# 2                               16
# 3                               29
# 4                                7

# %% [markdown]
# ###### Again check for missing data

# %%
df.isna().sum()
# Out:
# REPORT_DATE                        0
# PEOPLE_DEATH_NEW_COUNT             0
# COUNTRY_SHORT_NAME                 0
# PEOPLE_POSITIVE_NEW_CASES_COUNT    0
# dtype: int64

# %% [markdown]
# ###### Take only datas of USA

# %%
usa = df[df['COUNTRY_SHORT_NAME']=='United States']
usa
# Out:
#         REPORT_DATE  PEOPLE_DEATH_NEW_COUNT COUNTRY_SHORT_NAME  \
# 0        2020-12-13                       1      United States
# 1        2020-07-13                       3      United States
# 2        2020-07-08                       1      United States
# 3        2021-02-16                       2      United States
# 4        2020-05-12                       1      United States
# ...             ...                     ...                ...
# 1538886  2020-01-21                       0      United States
# 1538887  2020-01-21                       0      United States
# 1538888  2020-01-21                       0      United States
# 1538889  2020-01-21                       0      United States
# 1538890  2020-01-21                       0      United States
#
#          PEOPLE_POSITIVE_NEW_CASES_COUNT
# 0                                    237
# 1                                      7
# 2                                     16
# 3                                     29
# 4                                      7
# ...                                  ...
# 1538886                                0
# 1538887                                0
# 1538888                                0
# 1538889                                0
# 1538890                                0
#
# [1509314 rows x 4 columns]

# %% [markdown]
# ###### Take cases data

# %%
usa_cases = usa[['REPORT_DATE','PEOPLE_POSITIVE_NEW_CASES_COUNT']]
usa_cases
# Out:
#         REPORT_DATE  PEOPLE_POSITIVE_NEW_CASES_COUNT
# 0        2020-12-13                              237
# 1        2020-07-13                                7
# 2        2020-07-08                               16
# 3        2021-02-16                               29
# 4        2020-05-12                                7
# ...             ...                              ...
# 1538886  2020-01-21                                0
# 1538887  2020-01-21                                0
# 1538888  2020-01-21                                0
# 1538889  2020-01-21                                0
# 1538890  2020-01-21                                0
#
# [1509314 rows x 2 columns]

# %% [markdown]
# ###### Aggregate the case reports happened on same dates

# %%
usa_cases = usa_cases.groupby('REPORT_DATE')['PEOPLE_POSITIVE_NEW_CASES_COUNT'].sum().reset_index()
usa_cases
# Out:
#     REPORT_DATE  PEOPLE_POSITIVE_NEW_CASES_COUNT
# 0    2020-01-21                                1
# 1    2020-01-22                                0
# 2    2020-01-23                                0
# 3    2020-01-24                                1
# 4    2020-01-25                                1
# ..          ...                              ...
# 456  2021-04-21                            60514
# 457  2021-04-22                            66358
# 458  2021-04-23                            63752
# 459  2021-04-24                            50575
# 460  2021-04-25                            33662
#
# [461 rows x 2 columns]

# %% [markdown]
# ###### Change the index of the dataframe to dates

# %%
usa_cases = usa_cases.set_index('REPORT_DATE')
usa_cases
# Out:
#              PEOPLE_POSITIVE_NEW_CASES_COUNT
# REPORT_DATE
# 2020-01-21                                 1
# 2020-01-22                                 0
# 2020-01-23                                 0
# 2020-01-24                                 1
# 2020-01-25                                 1
# ...                                      ...
# 2021-04-21                             60514
# 2021-04-22                             66358
# 2021-04-23                             63752
# 2021-04-24                             50575
# 2021-04-25                             33662
#
# [461 rows x 1 columns]

# %% [markdown]
# ###### Check the frequency followed by index dates

# %%
usa_cases.index
# Out:
# DatetimeIndex(['2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30',
#                ...
#                '2021-04-16', '2021-04-17', '2021-04-18', '2021-04-19',
#                '2021-04-20', '2021-04-21', '2021-04-22', '2021-04-23',
#                '2021-04-24', '2021-04-25'],
#               dtype='datetime64[ns]', name='REPORT_DATE', length=461, freq=None)

# %% [markdown]
# ###### Indicate the frequency is happening by day

# %%
usa_cases.index.freq='D'

# %%
usa_cases.index
# Out:
# DatetimeIndex(['2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30',
#                ...
#                '2021-04-16', '2021-04-17', '2021-04-18', '2021-04-19',
#                '2021-04-20', '2021-04-21', '2021-04-22', '2021-04-23',
#                '2021-04-24', '2021-04-25'],
#               dtype='datetime64[ns]', name='REPORT_DATE', length=461, freq='D')

# %% [markdown]
# # Visualization

# %%
usa_cases.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='REPORT_DATE'>

# %% [markdown]
# # ETS decomposition

# %% [markdown]
# ###### ETS decomposition of cases

# %%
from pylab import rcParams
rcParams['figure.figsize']=18,8
decomposition_usa_cases = sm.tsa.seasonal_decompose(usa_cases,model='additive')
decomposition_usa_cases.plot();

# %% [markdown]
# ###### Test for stationarity

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(usa_cases['PEOPLE_POSITIVE_NEW_CASES_COUNT'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic       -1.442165
# p-value                   0.561903
# # lags used              14.000000
# # observations          446.000000
# critical value (1%)      -3.445097
# critical value (5%)      -2.868042
# critical value (10%)     -2.570233
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %% [markdown]
# # Train test split

# %%
len(usa_cases)
# Out:
# 461

# %%
461-60
# Out:
# 401

# %%
train_usa_cases = usa_cases.iloc[:401]
test_usa_cases = usa_cases.iloc[401:]

# %%
len(test_usa_cases)
# Out:
# 60

# %% [markdown]
# ### Find the best model

# %%
#Now let's use the SARIMAX function
from pmdarima import auto_arima

# %%
model_cases = auto_arima(usa_cases['PEOPLE_POSITIVE_NEW_CASES_COUNT'],seasonal=True,m=7,trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=10125.751, Time=0.53 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=10359.998, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=10158.874, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=10135.936, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=10358.007, Time=0.01 sec
#  ARIMA(2,1,2)(0,0,1)[7] intercept   : AIC=10132.334, Time=0.27 sec
#  ARIMA(2,1,2)(1,0,0)[7] intercept   : AIC=10125.886, Time=0.40 sec
#  ARIMA(2,1,2)(2,0,1)[7] intercept   : AIC=10126.383, Time=0.54 sec
#  ARIMA(2,1,2)(1,0,2)[7] intercept   : AIC=inf, Time=1.27 sec
#  ARIMA(2,1,2)(0,0,0)[7] intercept   : AIC=10232.864, Time=0.27 sec
#  ARIMA(2,1,2)(0,0,2)[7] intercept   : AIC=10127.460, Time=0.56 sec
#  ARIMA(2,1,2)(2,0,0)[7] intercept   : AIC=10127.339, Time=0.57 sec
#  ARIMA(2,1,2)(2,0,2)[7] intercept   : AIC=inf, Time=1.48 sec
#  ARIMA(1,1,2)(1,0,1)[7] intercept   : AIC=10126.721, Time=0.37 sec
#  ARIMA(2,1,1)(1,0,1)[7] intercept   : AIC=10132.924, Time=0.28 sec
#  ARIMA(3,1,2)(1,0,1)[7] intercept   : AIC=10124.053, Time=0.41 sec
#  ARIMA(3,1,2)(0,0,1)[7] intercept   : AIC=10106.208, Time=1.04 sec
#  ARIMA(3,1,2)(0,0,0)[7] intercept   : AIC=10171.637, Time=0.46 sec
#  ARIMA(3,1,2)(0,0,2)[7] intercept   : AIC=10125.881, Time=0.46 sec
#  ARIMA(3,1,2)(1,0,0)[7] intercept   : AIC=10114.556, Time=0.82 sec
#  ARIMA(3,1,2)(1,0,2)[7] intercept   : AIC=10099.390, Time=0.95 sec
#  ARIMA(3,1,2)(2,0,2)[7] intercept   : AIC=10099.819, Time=1.42 sec
#  ARIMA(3,1,2)(2,0,1)[7] intercept   : AIC=10124.528, Time=0.74 sec
#  ARIMA(3,1,1)(1,0,2)[7] intercept   : AIC=10109.492, Time=0.59 sec
#  ARIMA(4,1,2)(1,0,2)[7] intercept   : AIC=10097.624, Time=1.54 sec
#  ARIMA(4,1,2)(0,0,2)[7] intercept   : AIC=10098.635, Time=1.60 sec
#  ARIMA(4,1,2)(1,0,1)[7] intercept   : AIC=10098.831, Time=1.19 sec
#  ARIMA(4,1,2)(2,0,2)[7] intercept   : AIC=10098.582, Time=1.78 sec
#  ARIMA(4,1,2)(0,0,1)[7] intercept   : AIC=10096.937, Time=0.96 sec
#  ARIMA(4,1,2)(0,0,0)[7] intercept   : AIC=10151.229, Time=0.73 sec
#  ARIMA(4,1,2)(1,0,0)[7] intercept   : AIC=10104.584, Time=1.04 sec
#  ARIMA(4,1,1)(0,0,1)[7] intercept   : AIC=10138.145, Time=0.27 sec
#  ARIMA(5,1,2)(0,0,1)[7] intercept   : AIC=10093.974, Time=1.42 sec
#  ARIMA(5,1,2)(0,0,0)[7] intercept   : AIC=10147.500, Time=0.86 sec
#  ARIMA(5,1,2)(1,0,1)[7] intercept   : AIC=10124.511, Time=1.07 sec
#  ARIMA(5,1,2)(0,0,2)[7] intercept   : AIC=10126.712, Time=0.73 sec
#  ARIMA(5,1,2)(1,0,0)[7] intercept   : AIC=10103.080, Time=1.40 sec
#  ARIMA(5,1,2)(1,0,2)[7] intercept   : AIC=10091.336, Time=1.90 sec
#  ARIMA(5,1,2)(2,0,2)[7] intercept   : AIC=10092.548, Time=2.07 sec
#  ARIMA(5,1,2)(2,0,1)[7] intercept   : AIC=10125.117, Time=1.98 sec
#  ARIMA(5,1,1)(1,0,2)[7] intercept   : AIC=inf, Time=1.69 sec
#  ARIMA(5,1,3)(1,0,2)[7] intercept   : AIC=10097.597, Time=2.02 sec
#  ARIMA(4,1,1)(1,0,2)[7] intercept   : AIC=10105.749, Time=1.12 sec
#  ARIMA(4,1,3)(1,0,2)[7] intercept   : AIC=10104.786, Time=1.91 sec
#  ARIMA(5,1,2)(1,0,2)[7]             : AIC=10084.565, Time=2.01 sec
#  ARIMA(5,1,2)(0,0,2)[7]             : AIC=10124.794, Time=0.75 sec
#  ARIMA(5,1,2)(1,0,1)[7]             : AIC=10122.578, Time=1.14 sec
#  ARIMA(5,1,2)(2,0,2)[7]             : AIC=10086.397, Time=2.00 sec
#  ARIMA(5,1,2)(0,0,1)[7]             : AIC=10093.383, Time=1.32 sec
#  ARIMA(5,1,2)(2,0,1)[7]             : AIC=10123.734, Time=1.14 sec
#  ARIMA(4,1,2)(1,0,2)[7]             : AIC=10083.352, Time=1.56 sec
#  ARIMA(4,1,2)(0,0,2)[7]             : AIC=10096.624, Time=1.61 sec
#  ARIMA(4,1,2)(1,0,1)[7]             : AIC=10097.162, Time=1.23 sec
#  ARIMA(4,1,2)(2,0,2)[7]             : AIC=10086.309, Time=1.90 sec
#  ARIMA(4,1,2)(0,0,1)[7]             : AIC=10094.925, Time=1.32 sec
#  ARIMA(4,1,2)(2,0,1)[7]             : AIC=10098.718, Time=2.10 sec
#  ARIMA(3,1,2)(1,0,2)[7]             : AIC=10082.689, Time=1.35 sec
#  ARIMA(3,1,2)(0,0,2)[7]             : AIC=10123.849, Time=0.50 sec
#  ARIMA(3,1,2)(1,0,1)[7]             : AIC=10107.560, Time=1.06 sec
#  ARIMA(3,1,2)(2,0,2)[7]             : AIC=10084.100, Time=1.63 sec
#  ARIMA(3,1,2)(0,0,1)[7]             : AIC=10104.096, Time=1.22 sec
#  ARIMA(3,1,2)(2,0,1)[7]             : AIC=10110.532, Time=1.67 sec
#  ARIMA(2,1,2)(1,0,2)[7]             : AIC=10093.304, Time=0.67 sec
#  ARIMA(3,1,1)(1,0,2)[7]             : AIC=10103.213, Time=0.67 sec
#  ARIMA(3,1,3)(1,0,2)[7]             : AIC=10105.444, Time=1.80 sec
#  ARIMA(2,1,1)(1,0,2)[7]             : AIC=10102.141, Time=0.74 sec
#  ARIMA(2,1,3)(1,0,2)[7]             : AIC=10110.678, Time=1.23 sec
#  ARIMA(4,1,1)(1,0,2)[7]             : AIC=10101.179, Time=0.82 sec
#  ARIMA(4,1,3)(1,0,2)[7]             : AIC=10098.966, Time=1.81 sec
#
# Best model:  ARIMA(3,1,2)(1,0,2)[7]
# Total fit time: 74.218 seconds

# %%
model_cases.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                  461
# Model:             SARIMAX(3, 1, 2)x(1, 0, 2, 7)   Log Likelihood               -5032.345
# Date:                           Sat, 01 May 2021   AIC                          10082.689
# Time:                                   15:01:00   BIC                          10119.870
# Sample:                                        0   HQIC                         10097.330
#                                            - 461
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7374      0.100      7.356      0.000       0.541       0.934
# ar.L2         -0.1304      0.070     -1.862      0.063      -0.268       0.007
# ar.L3         -0.2219      0.080     -2.767      0.006      -0.379      -0.065
# ma.L1         -1.4119      0.098    -14.391      0.000      -1.604      -1.220
# ma.L2          0.7601      0.065     11.660      0.000       0.632       0.888
# ar.S.L7        0.9806      0.034     29.252      0.000       0.915       1.046
# ma.S.L7       -0.5718      0.043    -13.305      0.000      -0.656      -0.488
# ma.S.L14      -0.3088      0.043     -7.171      0.000      -0.393      -0.224
# sigma2       2.43e+08   2.66e-10   9.13e+17      0.000    2.43e+08    2.43e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):              9056.80
# Prob(Q):                              0.87   Prob(JB):                         0.00
# Heteroskedasticity (H):             104.35   Skew:                            -1.06
# Prob(H) (two-sided):                  0.00   Kurtosis:                        24.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.55e+33. Standard errors may be unstable.
# """

# %%
model_cases
# Out:
# ARIMA(order=(3, 1, 2), scoring_args={}, seasonal_order=(1, 0, 2, 7),
#       suppress_warnings=True, with_intercept=False)

# %% [markdown]
# ### Train the model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model_cases = SARIMAX(train_usa_cases['PEOPLE_POSITIVE_NEW_CASES_COUNT'],order=(3, 1, 2),seasonal_order=(1, 0, 2, 7),enforce_invertibility=False)

# %%
result_cases = model_cases.fit()
# Out:
# C:\Users\fawas\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
result_cases.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:     PEOPLE_POSITIVE_NEW_CASES_COUNT   No. Observations:                  401
# Model:               SARIMAX(3, 1, 2)x(1, 0, 2, 7)   Log Likelihood               -4394.070
# Date:                             Sat, 01 May 2021   AIC                           8806.140
# Time:                                     15:01:02   BIC                           8842.063
# Sample:                                 01-21-2020   HQIC                          8820.366
#                                       - 02-24-2021
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6485      0.653     -0.993      0.321      -1.928       0.631
# ar.L2         -0.2229      0.218     -1.022      0.307      -0.651       0.205
# ar.L3         -0.0938      0.101     -0.926      0.354      -0.292       0.105
# ma.L1         -0.0110      0.652     -0.017      0.987      -1.289       1.267
# ma.L2         -0.0876      0.369     -0.237      0.812      -0.811       0.636
# ar.S.L7        0.9766      0.036     27.473      0.000       0.907       1.046
# ma.S.L7       -0.5107      0.051    -10.070      0.000      -0.610      -0.411
# ma.S.L14      -0.3489      0.041     -8.480      0.000      -0.430      -0.268
# sigma2      2.591e+08   1.21e-08   2.14e+16      0.000    2.59e+08    2.59e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              8114.96
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):             119.45   Skew:                            -1.37
# Prob(H) (two-sided):                  0.00   Kurtosis:                        24.90
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.89e+31. Standard errors may be unstable.
# """

# %%
#Now we can predict the values into the future
start = len(train_usa_cases)
end = len(train_usa_cases) + len(test_usa_cases) - 1

# %%
prediction_cases = result_cases.predict(start,end).rename('SARIMA model')

# %%
test_usa_cases['PEOPLE_POSITIVE_NEW_CASES_COUNT'].plot(legend=True,figsize=(15,8))
prediction_cases.plot()
# Out:
# <AxesSubplot:xlabel='REPORT_DATE'>

# %% [markdown]
# # Forecast into unknown future

# %%
model_cases_fc = SARIMAX(usa_cases['PEOPLE_POSITIVE_NEW_CASES_COUNT'],order=(3, 1, 2),seasonal_order=(1, 0, 2, 7),enforce_invertibility=False)

# %%
result_cases_fc = model_cases_fc.fit()
# Out:
# C:\Users\fawas\Anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
fcast_cases = result_cases_fc.predict(len(usa_cases),len(usa_cases)+60,typ='levels').rename('SARIMA forecast')

# %%
usa_cases['PEOPLE_POSITIVE_NEW_CASES_COUNT'].plot(legend=True,figsize=(16,8))
fcast_cases.plot(legend=True)
# Out:
# <AxesSubplot:xlabel='REPORT_DATE'>
